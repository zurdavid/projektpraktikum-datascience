# %% [markdown]
# # Start

# %%
import sys
from importlib import reload

import pandas as pd

import fraud_detection as fd

# Add the src directory to the system path to import modules
reload(fd)
sys.path.append('../src')

datapath = "../data/transformed_label_and_damage.parquet"

# %%
df = fd.data_loader.load_data_df(datapath)

# %%
datapath = "../data/transformed_label_and_damage.parquet"

# %%
df = pd.read_csv("../model_comparison.csv")

# %%
df
# Out:
#           Unnamed: 0                          LGMB Classifier  \
# 0          precision                       0.8366917820162569
# 1             recall                        0.550024047658086
# 2                 f1                        0.663430931128931
# 3                mcc                       0.6708551295037856
# 4       damage_total                                 6015.164
# 5   damage_prevented                                 3539.678
# 6      damage_missed                                 2475.486
# 7     detected bonus                                   2353.0
# 8         fp penalty                                    920.0
# 9          Bewertung                                -1042.486
# 10                cm  [[28581.8    92. ]\n [  385.    470.6]]
#
#                       XGB Simple Classifier  \
# 0                        0.8392948361784172
# 1                        0.5542332076296661
# 2                        0.6670986860489452
# 3                        0.6744563683506748
# 4                                  6015.164
# 5                                  3562.548
# 6                        2452.6159999999995
# 7                                    2371.0
# 8                                     912.0
# 9                                  -993.616
# 10  [[28582.6    91.2]\n [  381.4   474.2]]
#
#                         CatBoost Classifier  \
# 0                        0.8533078202204418
# 1                        0.5448844072798819
# 2                        0.6647517561791247
# 3                        0.6745795512599128
# 4                                  6015.164
# 5                        3536.8559999999998
# 6                                  2478.308
# 7                                    2331.0
# 8                                     802.0
# 9                                  -949.308
# 10  [[28593.6    80.2]\n [  389.4   466.2]]
#
#                               XGBClassifier
# 0                        0.8476355868310603
# 1                        0.5490886484123081
# 2                        0.6661366913983777
# 3                        0.6748593753380819
# 4                                  6015.164
# 5                        3501.9020000000005
# 6                        2513.2619999999997
# 7                                    2349.0
# 8                                     846.0
# 9                                 -1010.262
# 10  [[28589.2    84.6]\n [  385.8   469.8]]

# %%
df2 = pd.read_csv("../model_comparison_2.csv")

# %%
df
# Out:
#           Unnamed: 0                          LGMB Classifier  \
# 0          precision                       0.8405190960434261
# 1             recall                       0.5397341094168443
# 2                 f1                       0.6573458318634938
# 3                mcc                       0.6661766526464136
# 4       damage_total                                 6015.164
# 5   damage_prevented                       3478.6179999999995
# 6      damage_missed                                 2536.546
# 7     detected bonus                                   2309.0
# 8         fp penalty                                    876.0
# 9          Bewertung                      -1103.5459999999998
# 10                cm  [[28586.2    87.6]\n [  393.8   461.8]]
#
#                       XGB Simple Classifier  \
# 0                        0.8446398463757359
# 1                        0.5343561786085151
# 2                        0.6545391816411984
# 3                        0.6644740581657367
# 4                                  6015.164
# 5                                  3464.916
# 6                                  2550.248
# 7                                    2286.0
# 8                                     840.0
# 9                                 -1104.248
# 10  [[28589.8    84. ]\n [  398.4   457.2]]
#
#                               XGBClassifier
# 0                        0.8515935902466965
# 1                        0.5334215991692627
# 2                        0.6559113126580064
# 3                        0.6667529046283611
# 4                                  6015.164
# 5                                  3458.204
# 6                                   2556.96
# 7                                    2282.0
# 8                                     794.0
# 9                       -1068.9599999999998
# 10  [[28594.4    79.4]\n [  399.2   456.4]]

# %%
df2
# Out:
#           Unnamed: 0                          LGMB Classifier  \
# 0          precision                       0.8449218373966005
# 1             recall                       0.5544611138437995
# 2                 f1                       0.6695141837893981
# 3                mcc                       0.6772250450865562
# 4       damage_total                                 6015.164
# 5   damage_prevented                                 3566.818
# 6      damage_missed                       2448.3459999999995
# 7     detected bonus                                   2372.0
# 8         fp penalty                                    870.0
# 9          Bewertung                       -946.3459999999999
# 10                cm  [[28586.8    87. ]\n [  381.2   474.4]]
#
#                       XGB Simple Classifier  \
# 0                        0.8413184161313365
# 1                        0.5535213422965513
# 2                         0.667699883735063
# 3                        0.6751234986424178
# 4                                  6015.164
# 5                                  3559.978
# 6                                  2455.186
# 7                                    2368.0
# 8                                     892.0
# 9                                  -979.186
# 10  [[28584.6    89.2]\n [  382.    473.6]]
#
#                               XGBClassifier
# 0                        0.8409889449549498
# 1                        0.5516532764934142
# 2                        0.6661983835197212
# 3                        0.6738016847192261
# 4                                  6015.164
# 5                                  3540.816
# 6                                  2474.348
# 7                                    2360.0
# 8                                     892.0
# 9                                 -1006.348
# 10  [[28584.6    89.2]\n [  383.6   472. ]]

# %% [markdown]
# # Model Vergleich
#
# Vergleich verschiedener Modelle mit Cross Validition auf identischen Splits.
#
# Die Combinded Modelle bestehen aus einem Klassifikator und einem Regressor, die zusammenarbeiten, um eine bessere Vorhersage zu erzielen.

# %%
# %%capture

X, _ = fd.data_loader.load_data_np(datapath)
neural_net = fd.neuralnets.train_nn.getNN(X.shape[1])

models = [
    ("LightGBM", fd.models.get_lgmb()),
    ("LightGBM Combined", fd.models.models.get_lgmb_clf_with_reg()),
    ("XGBoost", fd.models.get_xgb(10)),
    ("XGBoost Combined", fd.models.models.get_xgb_clf_with_reg(10)),
    # ("Neural Net", neural_net),
]

model_metrics = fd.model_comparison.compare_models(models, datapath, n_splits=5)

# %%
model_metrics_df = pd.DataFrame(model_metrics)
model_metrics_df.T
# Out:
#                   precision    recall        f1 damage_total damage_prevented  \
# LightGBM           0.798154  0.556331  0.655593     6015.164         3594.838
# LightGBM Combined   0.77612  0.580173   0.66301     6015.164         3748.506
# XGBoost            0.865924  0.513788  0.644868     6015.164         3350.516
# XGBoost Combined   0.816771  0.573401   0.67325     6015.164         3691.364
#
#                   damage_missed detected bonus fp penalty Bewertung  \
# LightGBM               2420.326         2380.0     1204.0 -1244.326
# LightGBM Combined      2266.658         2482.0     1450.0 -1234.658
# XGBoost                2664.648         2198.0      680.0 -1146.648
# XGBoost Combined         2323.8         2453.0     1110.0    -980.8
#
#                                                    cm
# LightGBM           [[28553.4, 120.4], [379.6, 476.0]]
# LightGBM Combined  [[28528.8, 145.0], [359.2, 496.4]]
# XGBoost             [[28605.8, 68.0], [416.0, 439.6]]
# XGBoost Combined   [[28562.8, 111.0], [365.0, 490.6]]

# %% [markdown]
# Das neuronale Netzwerk ist nocht recht unstabil und erzielt nicht immer gute Ergebnisse (in diesem Durchlauf schnitt es aber am besten ab).
